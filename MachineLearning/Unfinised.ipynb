# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import plot_model
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
from google.colab import files
from matplotlib import legend
import tensorflow as tf
import pandas as pd
import numpy as np
import datetime

def mae(test,pred):
  return tf.metrics.mae(y_true=test, y_pred=pred.squeeze())

def mse(test,pred):
  return tf.metrics.mse(y_true=test, y_pred=pred.squeeze())

def plot_predictions(train_data,train_labels,test_data,test_labels,predictions):
  plt.figure(figsize=(10, 7))
  plt.scatter(train_data, train_labels, c="b", label="Training data")
  plt.scatter(test_data, test_labels, c="g", label="Testing data")
  plt.scatter(test_data, predictions, c="r", label="Predictions")
  plt.legend();

# %% [markdown]
# Keep for later if its useful
#
# https://www.kaggle.com/datasets/ranatariq09/pqc-algorithms-benchmark-data

# %%
### This is dummy Data to see if the ML model works **used to create with ai**

# --- LOOKUP TABLES (For your reference) ---
# Ciphers: 0:Caesar, 1:Vigenere, 2:DES, 3:3DES, 4:AES-128, 5:AES-256, 6:RSA-2048
# Breakers: 0:Freq_Analysis, 1:Brute_Force, 2:Linear_Analyst, 3:Quantum_Shor, 4:Side_Channel

# --- THE DATA ARRAY ---
# Structure: [Cipher_ID, Breaker_ID, Key_Size, Time_to_Break_Log10]
# Note: Time is in Log10 scale (e.g., 5 means 10^5 seconds) because
# cryptographic time scales are too massive for standard linear arrays.

data = np.array([
    [0, 0, 256, -3.0],   # Caesar vs Freq Analysis (Fast)
    [0, 1, 256, -1.9],   # Caesar vs Brute Force
    [1, 0, 256, -1.0],   # Vigenere vs Freq Analysis
    [1, 1, 256, 2.0],    # Vigenere vs Brute Force
    [2, 1, 256, 4.9],    # DES vs Brute Force (~1 day)
    [2, 2, 256, 4.3],    # DES vs Linear Analyst
    [2, 3, 256, -0.3],   # DES vs Quantum (Very Fast)
    [3, 1, 256, 12.6],   # 3DES vs Brute Force
    [4, 1, 256, 25.0],   # AES-128 vs Brute Force (Near Impossible)
    [4, 4, 256, 3.5],    # AES-128 vs Side Channel
    [5, 1, 256, 60.0],   # AES-256 vs Brute Force (Impossible)
    [5, 4, 256, 3.8],    # AES-256 vs Side Channel
    [6, 3, 256, -1.1],   # RSA-2048 vs Quantum (Shor's Algorithm)
    [6, 1, 256, 50.0]    # RSA-2048 vs Brute Force
])
